# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# sibsp: # of sibling / spouses abroad the titanic
# parch: # of parents / children abroad the titanic
# embarked: port of embarkation. C = Cherbourg, Q = Queenstown, S = Southampton

# %%
train_pd = pd.read_csv('train.csv')
test_pd = pd.read_csv('test.csv')

display(train_pd)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
survived = train_pd['Survived']
train_pd = train_pd.drop(['Survived'], axis=1)

display(train_pd)

#survivor column dropped.
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
train_idx = train_pd['PassengerId']
test_idx = test_pd['PassengerId']

combined_pd = pd.concat([train_pd, test_pd]).reset_index(drop=True)

display(combined_pd)
# Out:
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            Braund, Mr. Owen Harris
# 1               2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               3       3                             Heikkinen, Miss. Laina
# 3               4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               5       3                           Allen, Mr. William Henry
# ...           ...     ...                                                ...
# 1304         1305       3                                 Spector, Mr. Woolf
# 1305         1306       1                       Oliva y Ocana, Dona. Fermina
# 1306         1307       3                       Saether, Mr. Simon Sivertsen
# 1307         1308       3                                Ware, Mr. Frederick
# 1308         1309       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0       male  22.0      1      0           A/5 21171    7.2500   NaN        S
# 1     female  38.0      1      0            PC 17599   71.2833   C85        C
# 2     female  26.0      0      0    STON/O2. 3101282    7.9250   NaN        S
# 3     female  35.0      1      0              113803   53.1000  C123        S
# 4       male  35.0      0      0              373450    8.0500   NaN        S
# ...      ...   ...    ...    ...                 ...       ...   ...      ...
# 1304    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 1305  female  39.0      0      0            PC 17758  108.9000  C105        C
# 1306    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307    male   NaN      0      0              359309    8.0500   NaN        S
# 1308    male   NaN      1      1                2668   22.3583   NaN        C
#
# [1309 rows x 11 columns]

# %%
print('NULL VALUES:')
print(combined_pd.isnull().sum())
# Out:
# NULL VALUES:
# PassengerId       0
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
# FILLING THE MISSING VALUES

y = combined_pd['Age'].value_counts() #count of individual ages
x = y.index.values # what the actual ages were

plt.figure(figsize=(10,5))
plt.bar(x,y)
plt.title('All Ages')
plt.show()
# ages on the x axis and number of people within those ages on y

class_age = combined_pd[['Pclass', 'Age']]

for i in range(1,4):
    plt.figure(figsize=(10,5))    
    plt.title('Class ' + str(i))
    y = class_age[class_age['Pclass'] == i]['Age'].value_counts()
    x = y.index.values
    
    plt.bar(x,y)
    plt.show()

medians = class_age.groupby('Pclass').median()
print(medians)
# Out:
#          Age
# Pclass
# 1       39.0
# 2       29.0
# 3       24.0

# %%
#filling the ages
for i in range(3):
    idx = np.where( (combined_pd['Pclass'] == i+1) & (combined_pd['Age'].isnull()) )[0]
    combined_pd.loc[idx, 'Age'] = medians.values[i][0]

display(combined_pd)
# Out:
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            Braund, Mr. Owen Harris
# 1               2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               3       3                             Heikkinen, Miss. Laina
# 3               4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               5       3                           Allen, Mr. William Henry
# ...           ...     ...                                                ...
# 1304         1305       3                                 Spector, Mr. Woolf
# 1305         1306       1                       Oliva y Ocana, Dona. Fermina
# 1306         1307       3                       Saether, Mr. Simon Sivertsen
# 1307         1308       3                                Ware, Mr. Frederick
# 1308         1309       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0       male  22.0      1      0           A/5 21171    7.2500   NaN        S
# 1     female  38.0      1      0            PC 17599   71.2833   C85        C
# 2     female  26.0      0      0    STON/O2. 3101282    7.9250   NaN        S
# 3     female  35.0      1      0              113803   53.1000  C123        S
# 4       male  35.0      0      0              373450    8.0500   NaN        S
# ...      ...   ...    ...    ...                 ...       ...   ...      ...
# 1304    male  24.0      0      0           A.5. 3236    8.0500   NaN        S
# 1305  female  39.0      0      0            PC 17758  108.9000  C105        C
# 1306    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307    male  24.0      0      0              359309    8.0500   NaN        S
# 1308    male  24.0      1      1                2668   22.3583   NaN        C
#
# [1309 rows x 11 columns]

# %%
display(combined_pd[combined_pd['Fare'].isnull()])

sim_fares = combined_pd[ (combined_pd['Pclass'] == 3) & (combined_pd['Embarked'] == 'S') ]['Fare']
print('Median: ', sim_fares.median()) # Median: 8.05

plt.hist(sim_fares)
plt.plot()

#combined_pd['Fare'].fillna(sim_fares.median(), inplace=True) did not work on pandas 3.0
combined_pd.fillna({'Fare': sim_fares.median()}, inplace=True)
# Out:
#       PassengerId  Pclass                Name   Sex   Age  SibSp  Parch  \
# 1043         1044       3  Storey, Mr. Thomas  male  60.5      0      0
#
#      Ticket  Fare Cabin Embarked
# 1043   3701   NaN   NaN        S
# Median:  8.05

# %%
display(combined_pd[combined_pd['Embarked'].isnull()])


sim_emb = combined_pd[ (combined_pd['Pclass'] == 1) & (combined_pd['Fare'] >= 70) & (combined_pd['Fare'] <= 90)]['Embarked']

print(sim_emb.value_counts())


#combined_pd['Fare'].fillna(sim_fares.median(), inplace=True) did not work on pandas 3.0
combined_pd.fillna({'Embarked': 'C'}, inplace=True)
# Out:
#      PassengerId  Pclass                                       Name     Sex  \
# 61            62       1                        Icard, Miss. Amelie  female
# 829          830       1  Stone, Mrs. George Nelson (Martha Evelyn)  female
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   38.0      0      0  113572  80.0   B28      NaN
# 829  62.0      0      0  113572  80.0   B28      NaN
# Embarked
# C    29
# S    25
# Q     3
# Name: count, dtype: int64

# %%
combined_pd.fillna({'Cabin': 'M'}, inplace=True)
#combined_pd['Cabin'].fillna('M', inplace=True)
combined_pd['Cabin'] = combined_pd['Cabin'].str[0]

print(combined_pd['Cabin'].value_counts())

idx = np.where(combined_pd['Cabin'] == 'T')[0]
combined_pd.loc[idx, 'Cabin'] = 'M'
# Out:
# Cabin
# M    1014
# C      94
# B      65
# D      46
# E      41
# A      22
# F      21
# G       5
# T       1
# Name: count, dtype: int64

# %%
display(combined_pd)

print(combined_pd.isnull().sum())

#cchhhheeccckk, preprocessing is done.
# Out:
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            Braund, Mr. Owen Harris
# 1               2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               3       3                             Heikkinen, Miss. Laina
# 3               4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               5       3                           Allen, Mr. William Henry
# ...           ...     ...                                                ...
# 1304         1305       3                                 Spector, Mr. Woolf
# 1305         1306       1                       Oliva y Ocana, Dona. Fermina
# 1306         1307       3                       Saether, Mr. Simon Sivertsen
# 1307         1308       3                                Ware, Mr. Frederick
# 1308         1309       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0       male  22.0      1      0           A/5 21171    7.2500     M        S
# 1     female  38.0      1      0            PC 17599   71.2833     C        C
# 2     female  26.0      0      0    STON/O2. 3101282    7.9250     M        S
# 3     female  35.0      1      0              113803   53.1000     C        S
# 4       male  35.0      0      0              373450    8.0500     M        S
# ...      ...   ...    ...    ...                 ...       ...   ...      ...
# 1304    male  24.0      0      0           A.5. 3236    8.0500     M        S
# 1305  female  39.0      0      0            PC 17758  108.9000     C        C
# 1306    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500     M        S
# 1307    male  24.0      0      0              359309    8.0500     M        S
# 1308    male  24.0      1      1                2668   22.3583     M        C
#
# [1309 rows x 11 columns]
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
print(combined_pd.nunique())

print(combined_pd['Pclass'].unique())
# Out:
# PassengerId    1309
# Pclass            3
# Name           1307
# Sex               2
# Age              98
# SibSp             7
# Parch             8
# Ticket          929
# Fare            281
# Cabin             8
# Embarked          3
# dtype: int64
# [3 1 2]

# %%
print(combined_pd['Name'].unique())

names = combined_pd['Name']

last_names = []
titles = []
first_names = []

for name in names:
    if ', ' not in name:
        last_name.append('')
    else:
        last, name = name.split(', ', 1)
        last_names.append(last)
        
    if '. ' not in name:
        titles.append('')
    else:
        title, first = name.split('. ', 1)
        titles.append(title)
        first_names.append(first)

last_names = np.array(last_names)
titles = np.array(titles)
first_names = np.array(first_names)

# grouping the titles, too much titles----------------------------------

idx = np.where(np.isin(titles, ['Capt', 'Col', 'Major']))
titles[idx] = 'Military'

idx = np.where(np.isin(titles, ['Don', 'Dona', 'Jonkheer', 'Lady', 'Sir', 'Master', 'the Countess']))
titles[idx] = 'Nobility'

idx = np.where(np.isin(titles, ['Miss', 'Mlle', 'Ms']))
titles[idx] = 'Ms'

idx = np.where(np.isin(titles, ['Mrs', 'Mme']))
titles[idx] = 'Mrs'

print ('\n')
print(np.unique(titles, return_counts=True))

combined_pd['Title'] = titles

display(combined_pd)
# Out:
# ['Braund, Mr. Owen Harris'
#  'Cumings, Mrs. John Bradley (Florence Briggs Thayer)'
#  'Heikkinen, Miss. Laina' ... 'Saether, Mr. Simon Sivertsen'
#  'Ware, Mr. Frederick' 'Peter, Master. Michael J']
#
#
# (array(['Dr', 'Military', 'Mr', 'Mrs', 'Ms', 'Nobility', 'Rev'],
#       dtype='<U12'), array([  8,   7, 757, 198, 264,  67,   8], dtype=int64))
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            Braund, Mr. Owen Harris
# 1               2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               3       3                             Heikkinen, Miss. Laina
# 3               4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               5       3                           Allen, Mr. William Henry
# ...           ...     ...                                                ...
# 1304         1305       3                                 Spector, Mr. Woolf
# 1305         1306       1                       Oliva y Ocana, Dona. Fermina
# 1306         1307       3                       Saether, Mr. Simon Sivertsen
# 1307         1308       3                                Ware, Mr. Frederick
# 1308         1309       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# 0       male  22.0      1      0           A/5 21171    7.2500     M        S
# 1     female  38.0      1      0            PC 17599   71.2833     C        C
# 2     female  26.0      0      0    STON/O2. 3101282    7.9250     M        S
# 3     female  35.0      1      0              113803   53.1000     C        S
# 4       male  35.0      0      0              373450    8.0500     M        S
# ...      ...   ...    ...    ...                 ...       ...   ...      ...
# 1304    male  24.0      0      0           A.5. 3236    8.0500     M        S
# 1305  female  39.0      0      0            PC 17758  108.9000     C        C
# 1306    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500     M        S
# 1307    male  24.0      0      0              359309    8.0500     M        S
# 1308    male  24.0      1      1                2668   22.3583     M        C
#
#          Title
# 0           Mr
# 1          Mrs
# 2           Ms
# 3          Mrs
# 4           Mr
# ...        ...
# 1304        Mr
# 1305  Nobility
# 1306        Mr
# 1307        Mr
# 1308  Nobility
#
# [1309 rows x 12 columns]

# %%
# categorizing ages by 10 years

print(combined_pd['Age'].min(), combined_pd['Age'].max()) #0.17-80

bins = np.array([0,10,20,30,40,50,60,70,80])

combined_pd['Age_Bin'] = pd.cut(combined_pd['Age'], bins)

display(combined_pd)
# Out:
# 0.17 80.0
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            Braund, Mr. Owen Harris
# 1               2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               3       3                             Heikkinen, Miss. Laina
# 3               4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               5       3                           Allen, Mr. William Henry
# ...           ...     ...                                                ...
# 1304         1305       3                                 Spector, Mr. Woolf
# 1305         1306       1                       Oliva y Ocana, Dona. Fermina
# 1306         1307       3                       Saether, Mr. Simon Sivertsen
# 1307         1308       3                                Ware, Mr. Frederick
# 1308         1309       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# 0       male  22.0      1      0           A/5 21171    7.2500     M        S
# 1     female  38.0      1      0            PC 17599   71.2833     C        C
# 2     female  26.0      0      0    STON/O2. 3101282    7.9250     M        S
# 3     female  35.0      1      0              113803   53.1000     C        S
# 4       male  35.0      0      0              373450    8.0500     M        S
# ...      ...   ...    ...    ...                 ...       ...   ...      ...
# 1304    male  24.0      0      0           A.5. 3236    8.0500     M        S
# 1305  female  39.0      0      0            PC 17758  108.9000     C        C
# 1306    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500     M        S
# 1307    male  24.0      0      0              359309    8.0500     M        S
# 1308    male  24.0      1      1                2668   22.3583     M        C
#
#          Title   Age_Bin
# 0           Mr  (20, 30]
# 1          Mrs  (30, 40]
# 2           Ms  (20, 30]
# 3          Mrs  (30, 40]
# 4           Mr  (30, 40]
# ...        ...       ...
# 1304        Mr  (20, 30]
# 1305  Nobility  (30, 40]
# 1306        Mr  (30, 40]
# 1307        Mr  (20, 30]
# 1308  Nobility  (20, 30]
#
# [1309 rows x 13 columns]

# %%
# organising ticket

ticket_dict = dict(combined_pd['Ticket'].value_counts())

combined_pd['tkt_count'] = combined_pd['Ticket'].map(ticket_dict)

display(combined_pd)
# Out:
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            Braund, Mr. Owen Harris
# 1               2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               3       3                             Heikkinen, Miss. Laina
# 3               4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               5       3                           Allen, Mr. William Henry
# ...           ...     ...                                                ...
# 1304         1305       3                                 Spector, Mr. Woolf
# 1305         1306       1                       Oliva y Ocana, Dona. Fermina
# 1306         1307       3                       Saether, Mr. Simon Sivertsen
# 1307         1308       3                                Ware, Mr. Frederick
# 1308         1309       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# 0       male  22.0      1      0           A/5 21171    7.2500     M        S
# 1     female  38.0      1      0            PC 17599   71.2833     C        C
# 2     female  26.0      0      0    STON/O2. 3101282    7.9250     M        S
# 3     female  35.0      1      0              113803   53.1000     C        S
# 4       male  35.0      0      0              373450    8.0500     M        S
# ...      ...   ...    ...    ...                 ...       ...   ...      ...
# 1304    male  24.0      0      0           A.5. 3236    8.0500     M        S
# 1305  female  39.0      0      0            PC 17758  108.9000     C        C
# 1306    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500     M        S
# 1307    male  24.0      0      0              359309    8.0500     M        S
# 1308    male  24.0      1      1                2668   22.3583     M        C
#
#          Title   Age_Bin  tkt_count
# 0           Mr  (20, 30]          1
# 1          Mrs  (30, 40]          2
# 2           Ms  (20, 30]          1
# 3          Mrs  (30, 40]          2
# 4           Mr  (30, 40]          1
# ...        ...       ...        ...
# 1304        Mr  (20, 30]          1
# 1305  Nobility  (30, 40]          3
# 1306        Mr  (30, 40]          1
# 1307        Mr  (20, 30]          1
# 1308  Nobility  (20, 30]          3
#
# [1309 rows x 14 columns]

# %%
combined_pd['Fare_per_Ticket'] = combined_pd['Fare']/combined_pd['tkt_count']

plt.bar(combined_pd['Fare_per_Ticket'].value_counts().index.values, combined_pd['Fare_per_Ticket'].value_counts())
plt.show

print(combined_pd['Fare_per_Ticket'].min(), combined_pd['Fare_per_Ticket'].max()) # 0 - 125.0823

bins = [0,20,40,60,80,150]
combined_pd['Fare_Bin'] = pd.cut(combined_pd['Fare_per_Ticket'], bins)

display(combined_pd)
# Out:
# 0.0 128.0823
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            Braund, Mr. Owen Harris
# 1               2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               3       3                             Heikkinen, Miss. Laina
# 3               4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               5       3                           Allen, Mr. William Henry
# ...           ...     ...                                                ...
# 1304         1305       3                                 Spector, Mr. Woolf
# 1305         1306       1                       Oliva y Ocana, Dona. Fermina
# 1306         1307       3                       Saether, Mr. Simon Sivertsen
# 1307         1308       3                                Ware, Mr. Frederick
# 1308         1309       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# 0       male  22.0      1      0           A/5 21171    7.2500     M        S
# 1     female  38.0      1      0            PC 17599   71.2833     C        C
# 2     female  26.0      0      0    STON/O2. 3101282    7.9250     M        S
# 3     female  35.0      1      0              113803   53.1000     C        S
# 4       male  35.0      0      0              373450    8.0500     M        S
# ...      ...   ...    ...    ...                 ...       ...   ...      ...
# 1304    male  24.0      0      0           A.5. 3236    8.0500     M        S
# 1305  female  39.0      0      0            PC 17758  108.9000     C        C
# 1306    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500     M        S
# 1307    male  24.0      0      0              359309    8.0500     M        S
# 1308    male  24.0      1      1                2668   22.3583     M        C
#
#          Title   Age_Bin  tkt_count  Fare_per_Ticket  Fare_Bin
# 0           Mr  (20, 30]          1         7.250000   (0, 20]
# 1          Mrs  (30, 40]          2        35.641650  (20, 40]
# 2           Ms  (20, 30]          1         7.925000   (0, 20]
# 3          Mrs  (30, 40]          2        26.550000  (20, 40]
# 4           Mr  (30, 40]          1         8.050000   (0, 20]
# ...        ...       ...        ...              ...       ...
# 1304        Mr  (20, 30]          1         8.050000   (0, 20]
# 1305  Nobility  (30, 40]          3        36.300000  (20, 40]
# 1306        Mr  (30, 40]          1         7.250000   (0, 20]
# 1307        Mr  (20, 30]          1         8.050000   (0, 20]
# 1308  Nobility  (20, 30]          3         7.452767   (0, 20]
#
# [1309 rows x 16 columns]

# %%
combined_pd['Num_family'] = combined_pd['SibSp'] + combined_pd['Parch'] + 1

display(combined_pd)
# Out:
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            Braund, Mr. Owen Harris
# 1               2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               3       3                             Heikkinen, Miss. Laina
# 3               4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               5       3                           Allen, Mr. William Henry
# ...           ...     ...                                                ...
# 1304         1305       3                                 Spector, Mr. Woolf
# 1305         1306       1                       Oliva y Ocana, Dona. Fermina
# 1306         1307       3                       Saether, Mr. Simon Sivertsen
# 1307         1308       3                                Ware, Mr. Frederick
# 1308         1309       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# 0       male  22.0      1      0           A/5 21171    7.2500     M        S
# 1     female  38.0      1      0            PC 17599   71.2833     C        C
# 2     female  26.0      0      0    STON/O2. 3101282    7.9250     M        S
# 3     female  35.0      1      0              113803   53.1000     C        S
# 4       male  35.0      0      0              373450    8.0500     M        S
# ...      ...   ...    ...    ...                 ...       ...   ...      ...
# 1304    male  24.0      0      0           A.5. 3236    8.0500     M        S
# 1305  female  39.0      0      0            PC 17758  108.9000     C        C
# 1306    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500     M        S
# 1307    male  24.0      0      0              359309    8.0500     M        S
# 1308    male  24.0      1      1                2668   22.3583     M        C
#
#          Title   Age_Bin  tkt_count  Fare_per_Ticket  Fare_Bin  Num_family
# 0           Mr  (20, 30]          1         7.250000   (0, 20]           2
# 1          Mrs  (30, 40]          2        35.641650  (20, 40]           2
# 2           Ms  (20, 30]          1         7.925000   (0, 20]           1
# 3          Mrs  (30, 40]          2        26.550000  (20, 40]           2
# 4           Mr  (30, 40]          1         8.050000   (0, 20]           1
# ...        ...       ...        ...              ...       ...         ...
# 1304        Mr  (20, 30]          1         8.050000   (0, 20]           1
# 1305  Nobility  (30, 40]          3        36.300000  (20, 40]           1
# 1306        Mr  (30, 40]          1         7.250000   (0, 20]           1
# 1307        Mr  (20, 30]          1         8.050000   (0, 20]           1
# 1308  Nobility  (20, 30]          3         7.452767   (0, 20]           3
#
# [1309 rows x 17 columns]

# %%
combined_pd.drop(['Name', 'Age', 'Ticket', 'Fare', 'tkt_count', 'Fare_per_Ticket'], axis=1, inplace=True)

display(combined_pd)
# Out:
#       PassengerId  Pclass     Sex  SibSp  Parch Cabin Embarked     Title  \
# 0               1       3    male      1      0     M        S        Mr
# 1               2       1  female      1      0     C        C       Mrs
# 2               3       3  female      0      0     M        S        Ms
# 3               4       1  female      1      0     C        S       Mrs
# 4               5       3    male      0      0     M        S        Mr
# ...           ...     ...     ...    ...    ...   ...      ...       ...
# 1304         1305       3    male      0      0     M        S        Mr
# 1305         1306       1  female      0      0     C        C  Nobility
# 1306         1307       3    male      0      0     M        S        Mr
# 1307         1308       3    male      0      0     M        S        Mr
# 1308         1309       3    male      1      1     M        C  Nobility
#
#        Age_Bin  Fare_Bin  Num_family
# 0     (20, 30]   (0, 20]           2
# 1     (30, 40]  (20, 40]           2
# 2     (20, 30]   (0, 20]           1
# 3     (30, 40]  (20, 40]           2
# 4     (30, 40]   (0, 20]           1
# ...        ...       ...         ...
# 1304  (20, 30]   (0, 20]           1
# 1305  (30, 40]  (20, 40]           1
# 1306  (30, 40]   (0, 20]           1
# 1307  (20, 30]   (0, 20]           1
# 1308  (20, 30]   (0, 20]           3
#
# [1309 rows x 11 columns]

# %%
print(combined_pd.nunique())
# Out:
# PassengerId    1309
# Pclass            3
# Sex               2
# SibSp             7
# Parch             8
# Cabin             8
# Embarked          3
# Title             7
# Age_Bin           8
# Fare_Bin          5
# Num_family        9
# dtype: int64

# %%
# RANDOM FOREST ALGORITHM

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler

# %%
combined_pd.set_index('PassengerId', inplace=True)

display(combined_pd)
# Out:
#              Pclass     Sex  SibSp  Parch Cabin Embarked     Title   Age_Bin  \
# PassengerId
# 1                 3    male      1      0     M        S        Mr  (20, 30]
# 2                 1  female      1      0     C        C       Mrs  (30, 40]
# 3                 3  female      0      0     M        S        Ms  (20, 30]
# 4                 1  female      1      0     C        S       Mrs  (30, 40]
# 5                 3    male      0      0     M        S        Mr  (30, 40]
# ...             ...     ...    ...    ...   ...      ...       ...       ...
# 1305              3    male      0      0     M        S        Mr  (20, 30]
# 1306              1  female      0      0     C        C  Nobility  (30, 40]
# 1307              3    male      0      0     M        S        Mr  (30, 40]
# 1308              3    male      0      0     M        S        Mr  (20, 30]
# 1309              3    male      1      1     M        C  Nobility  (20, 30]
#
#              Fare_Bin  Num_family
# PassengerId
# 1             (0, 20]           2
# 2            (20, 40]           2
# 3             (0, 20]           1
# 4            (20, 40]           2
# 5             (0, 20]           1
# ...               ...         ...
# 1305          (0, 20]           1
# 1306         (20, 40]           1
# 1307          (0, 20]           1
# 1308          (0, 20]           1
# 1309          (0, 20]           3
#
# [1309 rows x 10 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# make all the things same form 

label_enc = combined_pd.copy()
label_enc = label_enc.astype(str)

label_enc = label_enc.apply(LabelEncoder().fit_transform)

display(label_enc)
# Out:
#              Pclass  Sex  SibSp  Parch  Cabin  Embarked  Title  Age_Bin  \
# PassengerId
# 1                 2    1      1      0      7         2      2        2
# 2                 0    0      1      0      2         0      3        3
# 3                 2    0      0      0      7         2      4        2
# 4                 0    0      1      0      2         2      3        3
# 5                 2    1      0      0      7         2      2        3
# ...             ...  ...    ...    ...    ...       ...    ...      ...
# 1305              2    1      0      0      7         2      2        2
# 1306              0    0      0      0      2         0      5        3
# 1307              2    1      0      0      7         2      2        3
# 1308              2    1      0      0      7         2      2        2
# 1309              2    1      1      1      7         0      5        2
#
#              Fare_Bin  Num_family
# PassengerId
# 1                   0           2
# 2                   1           2
# 3                   0           0
# 4                   1           2
# 5                   0           0
# ...               ...         ...
# 1305                0           0
# 1306                1           0
# 1307                0           0
# 1308                0           0
# 1309                0           3
#
# [1309 rows x 10 columns]

# %%
# fixing 1-0's on few columns to true-false

one_hot = label_enc.copy()

one_hot = pd.get_dummies(one_hot, columns = ['Sex', 'Embarked', 'Title'])

display(one_hot)
# Out:
#              Pclass  SibSp  Parch  Cabin  Age_Bin  Fare_Bin  Num_family  \
# PassengerId
# 1                 2      1      0      7        2         0           2
# 2                 0      1      0      2        3         1           2
# 3                 2      0      0      7        2         0           0
# 4                 0      1      0      2        3         1           2
# 5                 2      0      0      7        3         0           0
# ...             ...    ...    ...    ...      ...       ...         ...
# 1305              2      0      0      7        2         0           0
# 1306              0      0      0      2        3         1           0
# 1307              2      0      0      7        3         0           0
# 1308              2      0      0      7        2         0           0
# 1309              2      1      1      7        2         0           3
#
#              Sex_0  Sex_1  Embarked_0  Embarked_1  Embarked_2  Title_0  \
# PassengerId
# 1            False   True       False       False        True    False
# 2             True  False        True       False       False    False
# 3             True  False       False       False        True    False
# 4             True  False       False       False        True    False
# 5            False   True       False       False        True    False
# ...            ...    ...         ...         ...         ...      ...
# 1305         False   True       False       False        True    False
# 1306          True  False        True       False       False    False
# 1307         False   True       False       False        True    False
# 1308         False   True       False       False        True    False
# 1309         False   True        True       False       False    False
#
#              Title_1  Title_2  Title_3  Title_4  Title_5  Title_6
# PassengerId
# 1              False     True    False    False    False    False
# 2              False    False     True    False    False    False
# 3              False    False    False     True    False    False
# 4              False    False     True    False    False    False
# 5              False     True    False    False    False    False
# ...              ...      ...      ...      ...      ...      ...
# 1305           False     True    False    False    False    False
# 1306           False    False    False    False     True    False
# 1307           False     True    False    False    False    False
# 1308           False     True    False    False    False    False
# 1309           False    False    False    False     True    False
#
# [1309 rows x 19 columns]

# %%
X = one_hot.loc[train_idx].values
y = survived.values

scaler = MinMaxScaler()
scaler.fit(X)
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=.2, random_state=0)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (712, 19) (179, 19) (712,) (179,)

# %% [markdown]
# RANDOM FOREST ALGHORITHM

# %%
# training classifiers

clf= RandomForestClassifier(random_state=0)
clf.fit(X_train, y_train).score(X_test, y_test)
# Out:
# 0.7932960893854749

# %%
# hyperparameter

params = { 'criterion':['gini','entropy'],
          'n_estimators':[20, 50, 100, 200, 300, 400, 500, 800, 1000],
          'max_depth':np.arange(3,50),
          'min_samples_split':np.arange(1,1000),
          'max_features':['sqrt', 'log2'],
          'max_samples':np.linspace(0.1, 0.9, 10) }

rand_search = RandomizedSearchCV(RandomForestClassifier(random_state=0), params, scoring='accuracy', random_state=0, cv=5)
rand_search.fit(X_train, y_train)

rand_params = rand_search.best_params_

print(rand_params, '\n')
print('Train Acc:', rand_search.best_score_)
preds = rand_search.predict(X_test)
print('Test Acc:', accuracy_score(preds, y_test))
# Out:
# {'n_estimators': 200, 'min_samples_split': 16, 'max_samples': 0.6333333333333333, 'max_features': 'sqrt', 'max_depth': 49, 'criterion': 'gini'}
#
# Train Acc: 0.8286417807544568
# Test Acc: 0.8324022346368715

# %%
n_estimators = np.linspace(rand_params['n_estimators']-10, rand_params['n_estimators']+10, 3).astype(int)

min_samples_split = np.arange(rand_params['min_samples_split']-3, rand_params['min_samples_split']+3).astype(int)

max_samples = np.linspace(rand_params['max_samples']-.05, rand_params['max_samples']+.05, 6)

max_depth = np.arange(rand_params['max_depth']-5, rand_params['max_depth']+5).astype(int)

params = { 'criterion':[rand_params['criterion']],
          'n_estimators':n_estimators,
          'max_depth':max_depth,
          'min_samples_split':min_samples_split,
          'max_features':[rand_params['max_features']],
          'max_samples':max_samples }

grid_search = GridSearchCV(RandomForestClassifier(random_state=0), params, scoring='accuracy', cv=5)
grid_search.fit(X_train, y_train)

grid_params = grid_search.best_params_

print(grid_params, '\n')
print('Train Acc:', grid_search.best_score_)
preds = grid_search.predict(X_test)
print('Test Acc:', accuracy_score(preds, y_test))
# Out:
# {'criterion': 'gini', 'max_depth': 44, 'max_features': 'sqrt', 'max_samples': 0.6233333333333333, 'min_samples_split': 14, 'n_estimators': 200}
#
# Train Acc: 0.8356544863587118
# Test Acc: 0.8212290502793296

# %% [markdown]
# ADABOOST ENTEGRASYONU DENEMESİ (????use SAMME.R algorithm?????) başarısız.

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
clf = AdaBoostClassifier(random_state=0)
clf.fit(X_train, y_train).score(X_test, y_test)
# Out:
# C:\Users\Mertcan Kahvecioğlu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# 0.8212290502793296

# %%
"""params = {'n_estimators': [50,100,200,300,400,500,800,1000],
          'learning_rate':[1.0, 0.1, 0.01, 0.001]}

rand_search = RandomizedSearchCV(AdaBoostClassifier(random_state=0), params, scoring='accuracy', random_state=0, cv=5)
rand_search.fit(X_train, y_train)

rand_params = rand_search.best_params_
print(rand_params, '\n')
print('Train Acc:', rand_search.best_score_)
preds = rand_search.predict(X_test)
print('Test Acc:', accuracy_score(preds, y_test))
# Out:
#   Cell In[30], line 1
#     """params = {'n_estimators': [50,100,200,300,400,500,800,1000],
#     ^
# SyntaxError: incomplete input
